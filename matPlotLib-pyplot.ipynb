# %% [markdown]
# # SISTEMAS DE APOIO A DECISÃO

# %% [markdown]
# ## Aula 10 - Introdução ao Data Science com Python

# %% [markdown]
# ## Aluno: Renan Odilon Oliveira

# %% [markdown]
# ## Matrícula: 0050008976

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

# %%
#Read in data into a dataframe
df = pd.read_csv('C:\JUPYTER_NOTEBOOK\GlobalLandTemperaturesByCity.csv')

#Show the first 5 rows of the table
df.tail(10)
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 8599202  2012-12-01               4.303                          0.341
# 8599203  2013-01-01               1.479                          0.217
# 8599204  2013-02-01               1.559                          0.304
# 8599205  2013-03-01               2.253                          0.267
# 8599206  2013-04-01               7.710                          0.182
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 8599202  Zwolle  Netherlands   52.24N     5.26E
# 8599203  Zwolle  Netherlands   52.24N     5.26E
# ...

# %%
df = pd.read_csv('C:\JUPYTER_NOTEBOOK\GlobalTemperatures.csv')
df.tail(10)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3182  2015-03-01                   6.740                              0.060
# 3183  2015-04-01                   9.313                              0.088
# 3184  2015-05-01                  12.312                              0.081
# 3185  2015-06-01                  14.505                              0.068
# 3186  2015-07-01                  15.051                              0.086
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# ...

# %%
df = pd.read_csv('C:\JUPYTER_NOTEBOOK\GlobalTemperatures.csv')
df.head(10)
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
# 5  1750-06-01                  12.937                              1.724
# 6  1750-07-01                  15.868                              1.911
# 7  1750-08-01                  14.750                              2.231
# 8  1750-09-01                  11.413                              2.637
# 9  1750-10-01                   6.367                              2.668
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# ...

# %%
df = df.ix[:,:2]
df.head()
# Out:
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573

# %%
df.describe()
# Out:
#        LandAverageTemperature
# count             3180.000000
# mean                 8.374731
# std                  4.381310
# min                 -2.080000
# 25%                  4.312000
# 50%                  8.610500
# 75%                 12.548250
# max                 19.021000

# %%
plt.figure(figsize = (15, 5))
plt.scatter(x = df['LandAverageTemperature'].index, y = df['LandAverageTemperature'])
plt.title("Temperatura média da Terra (1750-2015)")
plt.xlabel("Ano")
plt.ylabel("Temperatura media da Terra")
plt.show()
